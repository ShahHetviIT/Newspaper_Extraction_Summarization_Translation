# %% [markdown]
# # Installing required library

# %%
pip install --upgrade pip setuptools
# Out:
# ...
#
# ...
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# absl-py                       2.1.0
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.1.3
# anaconda-navigator            2.5.0
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# astunparse                    1.6.3
# ...

# %%
pip install pandas sqlalchemy mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)

# %%
pip install flask sqlalchemy pandas spacy pytextrank mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)

# %%
pip install GoogleNews
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)

# %%
pip install googletrans
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)

# %%
pip install aiohttp
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)

# %%
pip install --upgrade googletrans==4.0.0-rc1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)

# %%
pip install deep-translator
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)

# %%
pip install google-cloud-translate
# Out:
# ...
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.3 MB 558.9 kB/s eta 0:00:07
#    ---- ----------------------------------- 0.5/4.3 MB 558.9 kB/s eta 0:00:07
#    ------- -------------------------------- 0.8/4.3 MB 558.9 kB/s eta 0:00:07
#    ------- -------------------------------- 0.8/4.3 MB 558.9 kB/s eta 0:00:07
#    ------- -------------------------------- 0.8/4.3 MB 558.9 kB/s eta 0:00:07
#    --------- ------------------------------ 1.0/4.3 MB 553.0 kB/s eta 0:00:06
#    --------- ------------------------------ 1.0/4.3 MB 553.0 kB/s eta 0:00:06
#    ------------ --------------------------- 1.3/4.3 MB 541.1 kB/s eta 0:00:06
# ...

# %%
pip install boto3
# Out:
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.5 MB 987.4 kB/s eta 0:00:12
#    --- ------------------------------------ 1.0/12.5 MB 1.1 MB/s eta 0:00:11
#    --- ------------------------------------ 1.0/12.5 MB 1.1 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/12.5 MB 907.1 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.3/12.5 MB 907.1 kB/s eta 0:00:13
#    ----- ---------------------------------- 1.6/12.5 MB 830.6 kB/s eta 0:00:14
#    ----- ---------------------------------- 1.6/12.5 MB 830.6 kB/s eta 0:00:14
#    ----- ---------------------------------- 1.8/12.5 MB 860.4 kB/s eta 0:00:13
# ...

# %%
pip install import-ipynb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\khush\anaconda3\Lib\site-packages)

# %%
pip install pymysql

# %%
pip install pickle
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\khush\anaconda3\Lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
pip install glob
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\khush\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\khush\anaconda3\Lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement glob (from versions: none)
# ERROR: No matching distribution found for glob

# %%
pip install seaborn
# Out:
# ...
#
# ...

# %%
pip install sqlalchemy mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    -------------------- ------------------- 1.0/2.1 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/14.3 MB 4.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.8/14.3 MB 4.4 MB/s eta 0:00:03
#    -------- ------------------------------- 3.1/14.3 MB 5.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 4.2/14.3 MB 5.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.8/14.3 MB 5.6 MB/s eta 0:00:02
#    -------------------- ------------------- 7.3/14.3 MB 5.9 MB/s eta 0:00:02
# ...

# %%
pip install pymysql

# %%
import pymysql
import pandas as pd

def store_news_to_db(data):
    # Convert list of dictionaries to DataFrame
    df = pd.DataFrame(data)

    # Check if DataFrame is empty
    if df.empty:
        print("No data to store.")
        return

    # Database connection parameters
    connection = pymysql.connect(
        host='localhost',
        user='root',
        password='mysqlpassword',
        database='newsdb'
    )

    try:
        with connection.cursor() as cursor:
            # Truncate the table to remove existing data
            cursor.execute("TRUNCATE TABLE news_details")

            # Insert new data
            for _, row in df.iterrows():
                sql = """
                    INSERT INTO news_details (title, link, date, short_description, content)
                    VALUES (%s, %s, %s, %s, %s)
                """
                cursor.execute(sql, (row['title'], row['link'], row['date'], row['short_description'], row['content']))

            # Commit the transaction
            connection.commit()
            print("Data successfully stored in the database.")
    except Exception as e:
        print(f"Error storing data to database: {e}")
    finally:
        connection.close()

# %%
# database.py
import pymysql
import pandas as pd

def load_news_from_db():
    # Database connection parameters
    connection = pymysql.connect(
        host='localhost',
        user='root',
        password='mysqlpassword',
        database='newsdb'
    )
    
    try:
        query = "SELECT content FROM news_details"
        df = pd.read_sql(query, connection)
        return df
    finally:
        connection.close()

# %%
sample_data = [
    {
        'title': 'Sample News Title 1',
        'link': 'https://example.com/news1',
        'date': '2024-09-18',
        'short_description': 'This is a short description of news 1.',
        'content': 'Full content of the news article 1.'
    },
    {
        'title': 'Sample News Title 2',
        'link': 'https://example.com/news2',
        'date': '2024-09-18',
        'short_description': 'This is a short description of news 2.',
        'content': 'Full content of the news article 2.'
    }
]

# Call the function
store_news_to_db(sample_data)
# Out:
# Data successfully stored in the database.

# %%
pip install flask-cors
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 1.9 MB/s eta 0:00:07
#      --- ------------------------------------ 1.0/12.8 MB 2.0 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.6/12.8 MB 2.2 MB/s eta 0:00:06
#      ------- -------------------------------- 2.4/12.8 MB 2.4 MB/s eta 0:00:05
#      --------- ------------------------------ 2.9/12.8 MB 2.5 MB/s eta 0:00:05
#      ---------- ----------------------------- 3.4/12.8 MB 2.5 MB/s eta 0:00:04
#      ------------- -------------------------- 4.2/12.8 MB 2.6 MB/s eta 0:00:04
#      ------------- -------------------------- 4.5/12.8 MB 2.6 MB/s eta 0:00:04
#      ---------------- ----------------------- 5.2/12.8 MB 2.6 MB/s eta 0:00:03
#      ------------------ --------------------- 5.8/12.8 MB 2.6 MB/s eta 0:00:03
# ...

# %%
pip install googletrans
# Out:
# ...
#
# ...
